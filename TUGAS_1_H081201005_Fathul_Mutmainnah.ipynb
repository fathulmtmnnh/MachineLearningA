# %% [markdown]
# <a href="https://colab.research.google.com/github/fathulmtmnnh/MachineLearningA/blob/main/TUGAS_1_H081201005_Fathul_Mutmainnah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data')
df
# Out:
#                            Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                              NaN                      1990.000    2005.000
# 1                            World                     22674.116   30049.809
# 2    World  International Aviation                       258.941     422.777
# 3    World  International Shipping                       371.804     572.169
# 4                      Afghanistan                         2.546       1.063
# ..                             ...                           ...         ...
# 208                        Vietnam                        20.182      99.231
# 209                 Western Sahara                         0.144       0.227
# 210                          Yemen                         6.887      21.768
# 211                         Zambia                         2.955       2.457
# 212                       Zimbabwe                        17.178      11.388
#
# ...

# %% [markdown]
# Menghapus NaN

# %%
df1 = df.dropna()
df1
# Out:
#          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  Unnamed: 3  \
# 1          World                     22674.116   30049.809   37077.404
# 4    Afghanistan                         2.546       1.063      11.422
# 5        Albania                         6.583       4.196       5.026
# 6        Algeria                        65.677      98.197     159.929
# 7         Angola                         5.851      15.975      30.876
# ..           ...                           ...         ...         ...
# 207    Venezuela                       109.268     152.464     145.877
# 208      Vietnam                        20.182      99.231     218.729
# 210        Yemen                         6.887      21.768      12.503
# 211       Zambia                         2.955       2.457       4.967
# 212     Zimbabwe                        17.178      11.388      12.087
#
#     Fossil CO2 emissions Unnamed: 5 2017  Fossil CO2 emissions Unnamed: 7  \
# ...

# %% [markdown]
# Mengurutkan Country sesuai abjad

# %%
df2 = df1.sort_values('Country')
df2
# Out:
#                  Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 4            Afghanistan                         2.546       1.063
# 5                Albania                         6.583       4.196
# 6                Algeria                        65.677      98.197
# 7                 Angola                         5.851      15.975
# 9    Antigua and Barbuda                         0.223       0.283
# ..                   ...                           ...         ...
# 208              Vietnam                        20.182      99.231
# 1                  World                     22674.116   30049.809
# 210                Yemen                         6.887      21.768
# 211               Zambia                         2.955       2.457
# 212             Zimbabwe                        17.178      11.388
#
#      Unnamed: 3 Fossil CO2 emissions Unnamed: 5 2017  Fossil CO2 emissions  \
# 4        11.422                0.03%    348.60%                         18
# ...
